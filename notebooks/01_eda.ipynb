# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Computer Arena\\OneDrive\\Desktop\\Mlops MId project\\noshow-iq-66337\\data\\KaggleV2-May-2016.csv')

# %%
print(df.shape)
# Out:
# (110527, 14)

# %%
print(df.columns.tolist())
# Out:
# ['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay', 'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show']

# %%
print(df['No-show'].value_counts(normalize=True))
# Out:
# No-show
# No     0.798067
# Yes    0.201933
# Name: proportion, dtype: float64

# %%
print(df['Age'].describe())
# Out:
# count    110527.000000
# mean         37.088874
# std          23.110205
# min          -1.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: Age, dtype: float64

# %%
print(df.isna().sum())
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64
